# %%
import gymnasium as gym
import mcrafter
import stable_baselines3
from stable_baselines3.common.monitor import Monitor

# %%
# also inlcude train
env = gym.make('MCrafter-single-agent')
env = Monitor(env, filename='logs')
model = stable_baselines3.PPO('CnnPolicy', env, verbose=1, device='cuda', gamma=0.995, ent_coef=0.01)
model.learn(total_timesteps=350_000, progress_bar=True)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 383      |
# |    ep_rew_mean     | 650      |
# | time/              |          |
# |    fps             | 75       |
# |    iterations      | 1        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 399         |
# |    ep_rew_mean          | 738         |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 2           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.053572558 |
# |    clip_fraction        | 0.527       |
# ...
